# %%
from lerobot.policies.smolvla.modeling_smolvla import SmolVLAPolicy
policy = SmolVLAPolicy.from_pretrained("lerobot/smolvla_base")
# Out:
# WARNING:root:Device 'None' is not available. Switching to 'cuda'.
# Loading  HuggingFaceTB/SmolVLM2-500M-Video-Instruct weights ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 from lerobot.policies.smolvla.modeling_smolvla import SmolVLAPolicy
# ----> 2 policy = SmolVLAPolicy.from_pretrained("lerobot/smolvla_base")
#
# File ~/lerobot/src/lerobot/policies/pretrained.py:101, in PreTrainedPolicy.from_pretrained(cls, pretrained_name_or_path, config, force_download, resume_download, proxies, token, cache_dir, local_files_only, revision, strict, **kwargs)
#      89     config = PreTrainedConfig.from_pretrained(
#      90         pretrained_name_or_path=pretrained_name_or_path,
#      91         force_download=force_download,
#    (...)
#      98         **kwargs,
#      99     )
#     100 model_id = str(pretrained_name_or_path)
# --> 101 instance = cls(config, **kwargs)
#     102 if os.path.isdir(model_id):
#     103     print("Loading weights from local directory")
#
# File ~/lerobot/src/lerobot/policies/smolvla/modeling_smolvla.py:357, in SmolVLAPolicy.__init__(self, config, dataset_stats)
#     352 self.unnormalize_outputs = Unnormalize(
#     353     config.output_features, config.normalization_mapping, dataset_stats
#     354 )
#     356 self.language_tokenizer = AutoProcessor.from_pretrained(self.config.vlm_model_name).tokenizer
# --> 357 self.model = VLAFlowMatching(config)
#     358 self.reset()
#
# File ~/lerobot/src/lerobot/policies/smolvla/modeling_smolvla.py:637, in VLAFlowMatching.__init__(self, config)
#     634 super().__init__()
#     635 self.config = config
# --> 637 self.vlm_with_expert = SmolVLMWithExpertModel(
#     638     model_id=self.config.vlm_model_name,
#     639     freeze_vision_encoder=self.config.freeze_vision_encoder,
#     640     train_expert_only=self.config.train_expert_only,
#     641     load_vlm_weights=self.config.load_vlm_weights,
#     642     attention_mode=self.config.attention_mode,
#     643     num_expert_layers=self.config.num_expert_layers,
#     644     num_vlm_layers=self.config.num_vlm_layers,
#     645     self_attn_every_n_layers=self.config.self_attn_every_n_layers,
#     646     expert_width_multiplier=self.config.expert_width_multiplier,
#     647 )
#     648 self.state_proj = nn.Linear(
#     649     self.config.max_state_dim, self.vlm_with_expert.config.text_config.hidden_size
#     650 )
#     651 self.action_in_proj = nn.Linear(self.config.max_action_dim, self.vlm_with_expert.expert_hidden_size)
#
# File ~/lerobot/src/lerobot/policies/smolvla/smolvlm_with_expert.py:78, in SmolVLMWithExpertModel.__init__(self, model_id, load_vlm_weights, train_expert_only, freeze_vision_encoder, attention_mode, num_expert_layers, num_vlm_layers, self_attn_every_n_layers, expert_width_multiplier)
#      76 if load_vlm_weights:
#      77     print(f"Loading  {model_id} weights ...")
# ---> 78     self.vlm = AutoModelForImageTextToText.from_pretrained(
#      79         model_id,
#      80         device_map="auto",
#      81         torch_dtype="bfloat16",
#      82         low_cpu_mem_usage=True,
#      83     )
#      84     config = self.vlm.config
#      85 else:
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     606 )
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/transformers/modeling_utils.py:311, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     309 old_dtype = torch.get_default_dtype()
#     310 try:
# --> 311     return func(*args, **kwargs)
#     312 finally:
#     313     torch.set_default_dtype(old_dtype)
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/transformers/modeling_utils.py:4839, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4829     if dtype_orig is not None:
#    4830         torch.set_default_dtype(dtype_orig)
#    4832     (
#    4833         model,
#    4834         missing_keys,
#    4835         unexpected_keys,
#    4836         mismatched_keys,
#    4837         offload_index,
#    4838         error_msgs,
# -> 4839     ) = cls._load_pretrained_model(
#    4840         model,
#    4841         state_dict,
#    4842         checkpoint_files,
#    4843         pretrained_model_name_or_path,
#    4844         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4845         sharded_metadata=sharded_metadata,
#    4846         device_map=device_map,
#    4847         disk_offload_folder=offload_folder,
#    4848         offload_state_dict=offload_state_dict,
#    4849         dtype=torch_dtype,
#    4850         hf_quantizer=hf_quantizer,
#    4851         keep_in_fp32_regex=keep_in_fp32_regex,
#    4852         device_mesh=device_mesh,
#    4853         key_mapping=key_mapping,
#    4854         weights_only=weights_only,
#    4855     )
#    4857 # record tp degree the model sharded to
#    4858 model._tp_size = tp_size
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/transformers/modeling_utils.py:5302, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    5299         args_list = logging.tqdm(args_list, desc="Loading checkpoint shards")
#    5301     for args in args_list:
# -> 5302         _error_msgs, disk_offload_index, cpu_offload_index = load_shard_file(args)
#    5303         error_msgs += _error_msgs
#    5305 # Adjust offloaded weights name and save if needed
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/transformers/modeling_utils.py:933, in load_shard_file(args)
#     931 # Skip it with fsdp on ranks other than 0
#     932 elif not (is_fsdp_enabled() and not is_local_dist_rank_0() and not is_quantized):
# --> 933     disk_offload_index, cpu_offload_index = _load_state_dict_into_meta_model(
#     934         model_to_load,
#     935         state_dict,
#     936         shard_file,
#     937         expected_keys,
#     938         reverse_key_renaming_mapping,
#     939         device_map=device_map,
#     940         disk_offload_folder=disk_offload_folder,
#     941         disk_offload_index=disk_offload_index,
#     942         cpu_offload_folder=cpu_offload_folder,
#     943         cpu_offload_index=cpu_offload_index,
#     944         hf_quantizer=hf_quantizer,
#     945         is_safetensors=is_offloaded_safetensors,
#     946         keep_in_fp32_regex=keep_in_fp32_regex,
#     947         unexpected_keys=unexpected_keys,
#     948         device_mesh=device_mesh,
#     949     )
#     951 return error_msgs, disk_offload_index, cpu_offload_index
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/transformers/modeling_utils.py:810, in _load_state_dict_into_meta_model(model, state_dict, shard_file, expected_keys, reverse_renaming_mapping, device_map, disk_offload_folder, disk_offload_index, cpu_offload_folder, cpu_offload_index, hf_quantizer, is_safetensors, keep_in_fp32_regex, unexpected_keys, device_mesh)
#     808 param = param[...]
#     809 if casting_dtype is not None:
# --> 810     param = param.to(casting_dtype)
#     811 if to_contiguous:
#     812     param = param.contiguous()
#
# RuntimeError: CUDA error: no kernel image is available for execution on the device
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
